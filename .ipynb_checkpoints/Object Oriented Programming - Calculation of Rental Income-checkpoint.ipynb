# %% [markdown]
# Hi Brandon, welcome back. Let's get started. (Remember you can enter quit or close to exit)
#
# While income, expenses or total investment == 0 = true
#     then
#     What would you like to enter income, expenses, or investments? If you're done entering values, enter calculate.
#
#     income:
#         income = 0
#         while true:
#             Do you have an income to add? (y/n)
#                 Y:
#                     take income
#                     income += moreIncome
#                 N:
#                     self.income = income
#                     break
#                 Else:
#                     please enter a valid input
#
#     expenses
#         expenses = 0
#         while true:
#             Do you have an expense to add? (y/n)
#                 Y:
#                     take moreexpense
#                     expense += moreexpense
#                 N:
#                     self.expense = expense
#                     break
#                 else:
#                     please enter a valid input
#
#     investments:
#         investments = 0
#         while true:
#             Do you have an investments to add? (y/n)
#                 Y:
#                     take moreinvestments
#                     investments += morinvestments
#                 N:
#                     self.investments = investments
#                     break
#     calculate:
#         if income == 0
#             This isn't a good investment.
#             calculate()
#         elif expenses == 0
#             How did you not have any expenses? Go for it!
#             calculate()
#         elif total investment == 0 = true
#             Investments cannot equal zero. Please enter some investment values.
#             investments()
#         else
#             calculate()
#         ROI = (income - expenses)*12 / investments
#
#
#     if user_input.lower( == 'quit' or 'close' or 'exit'):
#                 return "Time is money. See you later!"
#
#     else:
#         if income, expenses or total investment == 0 = true
#
#         else
#             calculateROI

# %%
class ROICalculator():
    
    incomes = 0
    expenses = 0
    investments = 0
    
    '''
    This calculator class will have income, expenses, and investments. 
    It will have three methods, take income, take expenses, take investments, 
    and calculate the CashonCash ROI.
    '''
    
    def __init__(self, income, expenses, investments):
        self.income = income
        self.expenses = expenses
        self.investments = investments
    
    def take_income(self):
        self.ticket_number = self.tickets.pop(0)
        self.parkingSpaces.pop(0)
        self.currentTicket['Ticket Number']=self.ticket_number
        self.currentTicket.update({ self.ticket_number: { 'paid' : False}})
        print(f'\nPlease take ticket number {self.ticket_number}.')
        print(f'\nTickets currently available: {self.tickets}')
        print(f'Spaces currently available: {self.parkingSpaces}')
    
    def take_income(self):
        self.ticket_number = self.tickets.pop(0)
        self.parkingSpaces.pop(0)
        self.currentTicket['Ticket Number']=self.ticket_number
        self.currentTicket.update({ self.ticket_number: { 'paid' : False}})
        print(f'\nPlease take ticket number {self.ticket_number}.')
        print(f'\nTickets currently available: {self.tickets}')
        print(f'Spaces currently available: {self.parkingSpaces}')
        
    def take_income(self):
        self.ticket_number = self.tickets.pop(0)
        self.parkingSpaces.pop(0)
        self.currentTicket['Ticket Number']=self.ticket_number
        self.currentTicket.update({ self.ticket_number: { 'paid' : False}})
        print(f'\nPlease take ticket number {self.ticket_number}.')
        print(f'\nTickets currently available: {self.tickets}')
        print(f'Spaces currently available: {self.parkingSpaces}')
        
    def calculate_roi(self):
        self.ticket_number = int(input('What is your ticket number? :'))
        if self.currentTicket[self.ticket_number]['paid'] == True:
            print ("Thank You, have a nice day")
        else:
            payment = int(input('How much will you be paying? :'))
            if payment:
                self.currentTicket.update({ self.ticket_number: { 'paid' : True}})
                print("Thank you, have a nice day!")
        self.parkingSpaces.append(int(self.ticket_number))
        self.tickets.append(int(self.ticket_number))

myGarage = ParkingGarage()

# %%
def takeData():
    print("Hi Brandon, welcome back. Let's get started. \n(Remember you can enter 'quit' or 'close' to exit)")
    
    while True:
        brandon_input = input("\nWhat would you like to enter income, expenses, or investments? \nIf you're done entering values, enter calculate. \n \n")
        
#         if (brandon_input == 'incomes'):
#             shoppingCart.checkOut()
#             break
            
#         elif (brandon_input == 'expenses'):
#             shoppingCart.addToCart()
            
        
#         elif (what_do == 'delete'):
#             shoppingCart.removeFromCart()
            
#         elif (what_do == 'show'):
#             shoppingCart.showCart()
        
#         else:
#             print("Please enter add, delete, show, or quit.")

        if (brandon_input.lower() == 'quit' or brandon_input.lower() == 'close' or brandon_input.lower() == 'exit'):
                return "Time is money. See you later!"
        
        else:
            print('\nYou will need to enter income, expenses, investments or calculate.')
            
takeData()
# Out:
# Hi Brandon, welcome back. Let's get started.
# (Remember you can enter 'quit' or 'close' to exit)
#
# What would you like to enter income, expenses, or investments?
# If you're done entering values, enter calculate.
#
# what?
#
# You will need to enter income, expenses, investments or calculate.
#
# What would you like to enter income, expenses, or investments?
# If you're done entering values, enter calculate.
#
# this
#
# You will need to enter income, expenses, investments or calculate.
#
# What would you like to enter income, expenses, or investments?
# If you're done entering values, enter calculate.
#
# income
#
# You will need to enter income, expenses, investments or calculate.
#
# What would you like to enter income, expenses, or investments?
# If you're done entering values, enter calculate.
#
# quit
# 'Time is money. See you later!'
